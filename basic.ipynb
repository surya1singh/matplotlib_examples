# %%
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %% [markdown]
# # simple plotting

# %%
x = [4,0,0,4,4,0]
y = [6,6,3,3,0,0]
plt.plot(x, y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Showing letter S')
plt.show()

# %%
x = [4,0,0,4,4,0]
y = [6,6,3,3,0,0]
plt.plot(x, y, label='First Plot')
x2 = [6,10,14,6,14,6]
y2 = [0,6,0,3,3,0]
plt.plot(x2, y2, label='Second Plot')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Showing letter S')
plt.legend()
plt.show()

# %% [markdown]
# # bar charts and histograms

# %%
x = [0,2,4,6,8]
y = [4,2,1,4,5] 
plt.bar(x, y, label='Bar')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.legend()
plt.show()

# %%
x = [0,2,4,6,8]
y = [4,2,1,4,5] 

x2 = [1,3,5,7,9]
y2 = [8,2,1,5,3]

plt.bar(x, y, label='Bar1', color = 'c')
plt.bar(x2, y2, label='Bar2', color = '#a0a0a0' )
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.legend()
plt.show()

# %%
ages = [random.randrange(1,100,) for _ in range(1,21)]
ids = list(range(len(ages)))
plt.bar(ids, ages, label='Bar')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.legend()
plt.show()

# %%
ages = [random.randrange(1,100,) for _ in range(1,20)]
bins = list(range(0,max(ages) + 11 ,10 ))
plt.hist(ages, bins, histtype='bar',rwidth=0.8, label='hist')
plt.xlabel('Ages')
plt.ylabel('Total population ')
plt.legend()
plt.show()

# %% [markdown]
# # Scatter Plots

# %%
x = [random.randrange(1,15,) for _ in range(1,20)]
y = [random.randrange(1,15,) for _ in range(1,20)]
plt.scatter(x, y, label='scatter plot', color = '#090909')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
x = [random.randrange(1,15,) for _ in range(1,20)]
y = [random.randrange(1,15,) for _ in range(1,20)]
plt.scatter(x, y, label='scatter plot', marker='*', s=100)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# # Stack plots

# %%
x = [1,2,3,4,5,6]
y1 = [4,7,11,5,1,5]
y2 = [6,6,3,5,10,2]
y3 = [8,2,4,3,2,7]
y4 = [2,5,2,8,8,6]

plt.stackplot(x,y1,y2,y3,y4,colors = ['b','c','k','r'])
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.show()

# %%
plt.plot([],[],label='y1', color='b', linewidth = 5)
plt.plot([],[],label='y2', color='c', linewidth = 5)
plt.plot([],[],label='y3', color='k', linewidth = 5)
plt.plot([],[],label='y4', color='r', linewidth = 5)
plt.legend()
plt.stackplot(x,y1,y2,y3,y4,colors = ['b','c','k','r'])
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.show()

# %% [markdown]
# # Pie Charts

# %%
slices = [5,7,3,10]
lbls = ['f1','f2','f3','f4']
clrs = ['b','c','k','r']
plt.pie(slices, labels=lbls, colors=clrs)
plt.show()

# %%
slices = [4,2,3,12]
lbls = ['f1','f2','f3','f4']
clrs = ['b','c','#f0f080','red']
plt.pie(slices,
        labels=lbls,
        colors=clrs,
        startangle=90,
        shadow=True,
        explode=(0,0.2,0,0),
        autopct='% 1.2f% %')
plt.show()
